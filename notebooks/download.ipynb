# %%
# !pip install -i https://pypi.tuna.tsinghua.edu.cn/simple -r req.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'req.txt'

# %%
# !pip install -i https://pypi.tuna.tsinghua.edu.cn/simple modelscope
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting modelscope
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/64/92/b24fd3d91d87bf2189a422d6acea736505616b54706eadf141d2298c7a1b/modelscope-1.32.0-py3-none-any.whl (6.0 MB)
#      ---------------------------------------- 0.0/6.0 MB ? eta -:--:--
#      ------ --------------------------------- 1.0/6.0 MB 10.1 MB/s eta 0:00:01
#      ------------ --------------------------- 1.8/6.0 MB 5.3 MB/s eta 0:00:01
#      ------------ --------------------------- 1.8/6.0 MB 5.3 MB/s eta 0:00:01
#      ------------- -------------------------- 2.1/6.0 MB 3.5 MB/s eta 0:00:02
#      ------------------- -------------------- 2.9/6.0 MB 2.8 MB/s eta 0:00:02
#      -------------------- ------------------- 3.1/6.0 MB 2.7 MB/s eta 0:00:02
#      ---------------------- ----------------- 3.4/6.0 MB 2.6 MB/s eta 0:00:02
#      -------------------------- ------------- 3.9/6.0 MB 2.4 MB/s eta 0:00:01
#      --------------------------- ------------ 4.2/6.0 MB 2.4 MB/s eta 0:00:01
#      ------------------------------- -------- 4.7/6.0 MB 2.3 MB/s eta 0:00:01
#      -------------------------------- ------- 5.0/6.0 MB 2.2 MB/s eta 0:00:01
#      ---------------------------------- ----- 5.2/6.0 MB 2.2 MB/s eta 0:00:01
#      ------------------------------------ --- 5.5/6.0 MB 2.1 MB/s eta 0:00:01
#      ---------------------------------------- 6.0/6.0 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from modelscope) (3.9.0)
# Requirement already satisfied: requests>=2.25 in c:\users\hp\appdata\roaming\python\python310\site-packages (from modelscope) (2.32.3)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from modelscope) (65.6.3)
# Requirement already satisfied: tqdm>=4.64.0 in c:\programdata\anaconda3\lib\site-packages (from modelscope) (4.64.1)
# Requirement already satisfied: urllib3>=1.26 in c:\users\hp\appdata\roaming\python\python310\site-packages (from modelscope) (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\appdata\roaming\python\python310\site-packages (from requests>=2.25->modelscope) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\roaming\python\python310\site-packages (from requests>=2.25->modelscope) (3.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\appdata\roaming\python\python310\site-packages (from requests>=2.25->modelscope) (2024.8.30)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.64.0->modelscope) (0.4.6)
# Installing collected packages: modelscope
# Successfully installed modelscope-1.32.0
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
